# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import sys
import time

# Import the citipy library and the citipy module from the citipy library 
from citipy import citipy

# import for requests
import requests

# Import the API key.
sys.path.append("C:/Users/raney/OneDrive/Desktop/Analysis_Projects/World_Weather_Analysis")
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.00, high = 90.00, size = 2000)
lngs = np.random.uniform(low = -180.00, high = 180.00, size = 2000)
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities =[]

#Identify the nearest city for each lattitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # check for the city if already exists
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i%50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description})        

# If an error is experienced, skip the city.
    except:
        print(f"City {city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | algiers
# Processing Record 3 of Set 1 | mont-de-marsan
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | barentsburg
# City barentsburg not found. Skipping...
# Processing Record 6 of Set 1 | daru
# Processing Record 7 of Set 1 | san patricio
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | te anau
# Processing Record 11 of Set 1 | suixi
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | yuzhnyy
# Processing Record 14 of Set 1 | luwuk
# Processing Record 15 of Set 1 | black river
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | maiduguri
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | baykit
# Processing Record 22 of Set 1 | kenai
# Processing Record 23 of Set 1 | klyuchi
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | mentakab
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | cap malheureux
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | zyryanka
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | casa branca
# Processing Record 36 of Set 1 | omsukchan
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | puerto suarez
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | gazimurskiy zavod
# Processing Record 42 of Set 1 | taolanaro
# City taolanaro not found. Skipping...
# Processing Record 43 of Set 1 | adrar
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | kantemirovka
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | taoudenni
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | malwan
# City malwan not found. Skipping...
# Processing Record 2 of Set 2 | shingu
# Processing Record 3 of Set 2 | kiama
# Processing Record 4 of Set 2 | taltal
# Processing Record 5 of Set 2 | tetouan
# Processing Record 6 of Set 2 | qandala
# Processing Record 7 of Set 2 | pevek
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | palmer
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | sentyabrskiy
# City sentyabrskiy not found. Skipping...
# Processing Record 13 of Set 2 | umm lajj
# Processing Record 14 of Set 2 | kavaratti
# Processing Record 15 of Set 2 | killybegs
# Processing Record 16 of Set 2 | petatlan
# Processing Record 17 of Set 2 | nguiu
# City nguiu not found. Skipping...
# Processing Record 18 of Set 2 | oranjemund
# Processing Record 19 of Set 2 | kudymkar
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | marsa matruh
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | kurilsk
# Processing Record 24 of Set 2 | townsville
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | mehamn
# Processing Record 27 of Set 2 | gat
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | nhulunbuy
# Processing Record 30 of Set 2 | vestmannaeyjar
# Processing Record 31 of Set 2 | garissa
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | brae
# Processing Record 34 of Set 2 | arona
# Processing Record 35 of Set 2 | dembi dolo
# Processing Record 36 of Set 2 | ixtapa
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | hervey bay
# Processing Record 40 of Set 2 | port blair
# Processing Record 41 of Set 2 | leningradskiy
# Processing Record 42 of Set 2 | halalo
# City halalo not found. Skipping...
# Processing Record 43 of Set 2 | yar-sale
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | ardakan
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | illoqqortoormiut
# City illoqqortoormiut not found. Skipping...
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | semirara
# Processing Record 50 of Set 2 | saint anthony
# Processing Record 1 of Set 3 | mys shmidta
# City mys shmidta not found. Skipping...
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | arkhipo-osipovka
# Processing Record 4 of Set 3 | kismayo
# Processing Record 5 of Set 3 | tuatapere
# Processing Record 6 of Set 3 | ushtobe
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | kloulklubed
# Processing Record 9 of Set 3 | santa cruz
# Processing Record 10 of Set 3 | ushuaia
# Processing Record 11 of Set 3 | warqla
# City warqla not found. Skipping...
# Processing Record 12 of Set 3 | muhos
# Processing Record 13 of Set 3 | bahia honda
# Processing Record 14 of Set 3 | itarema
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | longyearbyen
# Processing Record 17 of Set 3 | port-gentil
# Processing Record 18 of Set 3 | aksu
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | avera
# Processing Record 22 of Set 3 | bulgan
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | college
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | asau
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | rio grande
# Processing Record 30 of Set 3 | la ronge
# Processing Record 31 of Set 3 | tevaitoa
# Processing Record 32 of Set 3 | egvekinot
# Processing Record 33 of Set 3 | touros
# Processing Record 34 of Set 3 | fairbanks
# Processing Record 35 of Set 3 | fortuna
# Processing Record 36 of Set 3 | cheuskiny
# City cheuskiny not found. Skipping...
# Processing Record 37 of Set 3 | alyangula
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | cape town
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | chimore
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | vao
# Processing Record 45 of Set 3 | cayenne
# Processing Record 46 of Set 3 | beloha
# Processing Record 47 of Set 3 | shangzhi
# Processing Record 48 of Set 3 | solnechnyy
# Processing Record 49 of Set 3 | klaksvik
# Processing Record 50 of Set 3 | sambava
# Processing Record 1 of Set 4 | sakakah
# Processing Record 2 of Set 4 | belmonte
# Processing Record 3 of Set 4 | richards bay
# Processing Record 4 of Set 4 | lorengau
# Processing Record 5 of Set 4 | alice springs
# Processing Record 6 of Set 4 | skjervoy
# Processing Record 7 of Set 4 | ferkessedougou
# Processing Record 8 of Set 4 | almaty
# Processing Record 9 of Set 4 | redcliffe
# Processing Record 10 of Set 4 | iquique
# Processing Record 11 of Set 4 | soledade
# Processing Record 12 of Set 4 | axim
# Processing Record 13 of Set 4 | boulder city
# Processing Record 14 of Set 4 | manga
# Processing Record 15 of Set 4 | novyy urengoy
# Processing Record 16 of Set 4 | dingle
# Processing Record 17 of Set 4 | isangel
# Processing Record 18 of Set 4 | da lat
# Processing Record 19 of Set 4 | orichi
# Processing Record 20 of Set 4 | aflu
# City aflu not found. Skipping...
# Processing Record 21 of Set 4 | mihijam
# Processing Record 22 of Set 4 | byron bay
# Processing Record 23 of Set 4 | nanortalik
# Processing Record 24 of Set 4 | lata
# Processing Record 25 of Set 4 | horodnytsya
# Processing Record 26 of Set 4 | attawapiskat
# City attawapiskat not found. Skipping...
# Processing Record 27 of Set 4 | ati
# Processing Record 28 of Set 4 | porto walter
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | iqaluit
# Processing Record 32 of Set 4 | severo-kurilsk
# Processing Record 33 of Set 4 | baisha
# Processing Record 34 of Set 4 | tevriz
# Processing Record 35 of Set 4 | san carlos de bariloche
# Processing Record 36 of Set 4 | sabang
# Processing Record 37 of Set 4 | bambous virieux
# Processing Record 38 of Set 4 | mount hagen
# Processing Record 39 of Set 4 | vozrozhdeniye
# Processing Record 40 of Set 4 | bubaque
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | puerto escondido
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | san jose
# Processing Record 46 of Set 4 | ecoporanga
# Processing Record 47 of Set 4 | tsihombe
# City tsihombe not found. Skipping...
# Processing Record 48 of Set 4 | shumskiy
# Processing Record 49 of Set 4 | mar del plata
# Processing Record 50 of Set 4 | samana
# Processing Record 1 of Set 5 | bonthe
# Processing Record 2 of Set 5 | plouzane
# Processing Record 3 of Set 5 | puerto narino
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | akdepe
# Processing Record 6 of Set 5 | san quintin
# Processing Record 7 of Set 5 | taber
# Processing Record 8 of Set 5 | batagay
# Processing Record 9 of Set 5 | itoman
# Processing Record 10 of Set 5 | stamsund
# City stamsund not found. Skipping...
# Processing Record 11 of Set 5 | tilichiki
# Processing Record 12 of Set 5 | gorlice
# Processing Record 13 of Set 5 | codrington
# Processing Record 14 of Set 5 | den helder
# Processing Record 15 of Set 5 | krasnoselkup
# Processing Record 16 of Set 5 | guilin
# Processing Record 17 of Set 5 | baruun-urt
# Processing Record 18 of Set 5 | mahibadhoo
# Processing Record 19 of Set 5 | novo aripuana
# Processing Record 20 of Set 5 | kirakira
# Processing Record 21 of Set 5 | yamada
# Processing Record 22 of Set 5 | beyneu
# Processing Record 23 of Set 5 | goderich
# Processing Record 24 of Set 5 | tartus
# Processing Record 25 of Set 5 | mayo
# Processing Record 26 of Set 5 | viligili
# City viligili not found. Skipping...
# Processing Record 27 of Set 5 | petropavlovka
# Processing Record 28 of Set 5 | nizhneyansk
# City nizhneyansk not found. Skipping...
# Processing Record 29 of Set 5 | ambilobe
# Processing Record 30 of Set 5 | lockhart
# Processing Record 31 of Set 5 | amderma
# City amderma not found. Skipping...
# Processing Record 32 of Set 5 | belushya guba
# City belushya guba not found. Skipping...
# Processing Record 33 of Set 5 | bahar
# Processing Record 34 of Set 5 | bartica
# Processing Record 35 of Set 5 | fare
# Processing Record 36 of Set 5 | lasa
# Processing Record 37 of Set 5 | gravdal
# Processing Record 38 of Set 5 | samusu
# City samusu not found. Skipping...
# Processing Record 39 of Set 5 | tumannyy
# City tumannyy not found. Skipping...
# Processing Record 40 of Set 5 | vrangel
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | iguape
# Processing Record 43 of Set 5 | vaitupu
# City vaitupu not found. Skipping...
# Processing Record 44 of Set 5 | qasigiannguit
# Processing Record 45 of Set 5 | mocuba
# Processing Record 46 of Set 5 | mubende
# Processing Record 47 of Set 5 | puerto ayora
# Processing Record 48 of Set 5 | kalmunai
# Processing Record 49 of Set 5 | coihaique
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | say
# Processing Record 2 of Set 6 | haines junction
# Processing Record 3 of Set 6 | mormugao
# Processing Record 4 of Set 6 | nantucket
# Processing Record 5 of Set 6 | tricase
# Processing Record 6 of Set 6 | kuusamo
# Processing Record 7 of Set 6 | urumqi
# Processing Record 8 of Set 6 | high rock
# Processing Record 9 of Set 6 | kodiak
# Processing Record 10 of Set 6 | takoradi
# Processing Record 11 of Set 6 | saint-denis
# Processing Record 12 of Set 6 | thompson
# Processing Record 13 of Set 6 | alausi
# Processing Record 14 of Set 6 | silvan
# Processing Record 15 of Set 6 | tasquillo
# Processing Record 16 of Set 6 | a
# City a not found. Skipping...
# Processing Record 17 of Set 6 | mildura
# Processing Record 18 of Set 6 | bandarbeyla
# Processing Record 19 of Set 6 | ulladulla
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | meulaboh
# Processing Record 22 of Set 6 | nambour
# Processing Record 23 of Set 6 | presque isle
# Processing Record 24 of Set 6 | suhbaatar
# Processing Record 25 of Set 6 | vikhorevka
# Processing Record 26 of Set 6 | tocopilla
# Processing Record 27 of Set 6 | kananga
# Processing Record 28 of Set 6 | giddalur
# Processing Record 29 of Set 6 | ban phai
# Processing Record 30 of Set 6 | galesong
# Processing Record 31 of Set 6 | port macquarie
# Processing Record 32 of Set 6 | zorritos
# Processing Record 33 of Set 6 | ipaba
# Processing Record 34 of Set 6 | parabel
# Processing Record 35 of Set 6 | tuy hoa
# Processing Record 36 of Set 6 | boyolangu
# Processing Record 37 of Set 6 | huangnihe
# Processing Record 38 of Set 6 | zeya
# Processing Record 39 of Set 6 | anloga
# Processing Record 40 of Set 6 | juxian
# City juxian not found. Skipping...
# Processing Record 41 of Set 6 | oktyabrskiy
# Processing Record 42 of Set 6 | gibara
# Processing Record 43 of Set 6 | ketchikan
# Processing Record 44 of Set 6 | sidi ali
# Processing Record 45 of Set 6 | tabou
# Processing Record 46 of Set 6 | kudahuvadhoo
# Processing Record 47 of Set 6 | paita
# Processing Record 48 of Set 6 | eirunepe
# Processing Record 49 of Set 6 | mandiana
# Processing Record 50 of Set 6 | beringovskiy
# Processing Record 1 of Set 7 | taperoa
# Processing Record 2 of Set 7 | maniitsoq
# Processing Record 3 of Set 7 | sujiatun
# Processing Record 4 of Set 7 | huntsville
# Processing Record 5 of Set 7 | norman wells
# Processing Record 6 of Set 7 | ahipara
# Processing Record 7 of Set 7 | north bend
# Processing Record 8 of Set 7 | marcona
# City marcona not found. Skipping...
# Processing Record 9 of Set 7 | svetlogorsk
# Processing Record 10 of Set 7 | hailin
# Processing Record 11 of Set 7 | raudeberg
# Processing Record 12 of Set 7 | viedma
# Processing Record 13 of Set 7 | columbus
# Processing Record 14 of Set 7 | qaanaaq
# Processing Record 15 of Set 7 | dasoguz
# Processing Record 16 of Set 7 | rocha
# Processing Record 17 of Set 7 | rawannawi
# City rawannawi not found. Skipping...
# Processing Record 18 of Set 7 | namibe
# Processing Record 19 of Set 7 | lagoa
# Processing Record 20 of Set 7 | sao filipe
# Processing Record 21 of Set 7 | cape canaveral
# Processing Record 22 of Set 7 | shurob
# Processing Record 23 of Set 7 | natal
# Processing Record 24 of Set 7 | luanda
# Processing Record 25 of Set 7 | kahului
# Processing Record 26 of Set 7 | acapulco
# Processing Record 27 of Set 7 | bathsheba
# Processing Record 28 of Set 7 | elat
# Processing Record 29 of Set 7 | maksatikha
# Processing Record 30 of Set 7 | ngukurr
# City ngukurr not found. Skipping...
# Processing Record 31 of Set 7 | salinas
# Processing Record 32 of Set 7 | sabha
# Processing Record 33 of Set 7 | comodoro rivadavia
# Processing Record 34 of Set 7 | coron
# Processing Record 35 of Set 7 | birao
# Processing Record 36 of Set 7 | kuito
# Processing Record 37 of Set 7 | kachiry
# Processing Record 38 of Set 7 | vardo
# Processing Record 39 of Set 7 | lukaya
# Processing Record 40 of Set 7 | namatanai
# Processing Record 41 of Set 7 | yerbogachen
# Processing Record 42 of Set 7 | koutsouras
# Processing Record 43 of Set 7 | nouadhibou
# Processing Record 44 of Set 7 | aripuana
# Processing Record 45 of Set 7 | miri
# Processing Record 46 of Set 7 | guerrero negro
# Processing Record 47 of Set 7 | sayyan
# Processing Record 48 of Set 7 | grand gaube
# Processing Record 49 of Set 7 | fort nelson
# Processing Record 50 of Set 7 | verkhnyaya inta
# Processing Record 1 of Set 8 | paamiut
# Processing Record 2 of Set 8 | ermelo
# Processing Record 3 of Set 8 | magan
# Processing Record 4 of Set 8 | biltine
# Processing Record 5 of Set 8 | kargat
# Processing Record 6 of Set 8 | bloemhof
# Processing Record 7 of Set 8 | mokolo
# Processing Record 8 of Set 8 | vanimo
# Processing Record 9 of Set 8 | harbour breton
# Processing Record 10 of Set 8 | saint-georges
# Processing Record 11 of Set 8 | upernavik
# Processing Record 12 of Set 8 | puerto rico
# Processing Record 13 of Set 8 | phun phin
# City phun phin not found. Skipping...
# Processing Record 14 of Set 8 | tabiauea
# City tabiauea not found. Skipping...
# Processing Record 15 of Set 8 | rio tuba
# Processing Record 16 of Set 8 | torbay
# Processing Record 17 of Set 8 | ostrovnoy
# Processing Record 18 of Set 8 | poum
# Processing Record 19 of Set 8 | chirongui
# Processing Record 20 of Set 8 | mecca
# Processing Record 21 of Set 8 | mount isa
# Processing Record 22 of Set 8 | sibolga
# Processing Record 23 of Set 8 | manokwari
# Processing Record 24 of Set 8 | ambon
# Processing Record 25 of Set 8 | waitati
# Processing Record 26 of Set 8 | constitucion
# Processing Record 27 of Set 8 | kampot
# Processing Record 28 of Set 8 | barrow
# Processing Record 29 of Set 8 | grand river south east
# City grand river south east not found. Skipping...
# Processing Record 30 of Set 8 | kichera
# Processing Record 31 of Set 8 | garowe
# Processing Record 32 of Set 8 | mackenzie
# Processing Record 33 of Set 8 | yanam
# Processing Record 34 of Set 8 | jinji
# Processing Record 35 of Set 8 | plaster rock
# Processing Record 36 of Set 8 | camana
# Processing Record 37 of Set 8 | hambantota
# Processing Record 38 of Set 8 | limbe
# Processing Record 39 of Set 8 | okato
# Processing Record 40 of Set 8 | pundaguitan
# Processing Record 41 of Set 8 | rolla
# Processing Record 42 of Set 8 | necochea
# Processing Record 43 of Set 8 | sao joao da barra
# Processing Record 44 of Set 8 | suez
# Processing Record 45 of Set 8 | hedaru
# Processing Record 46 of Set 8 | nelson bay
# Processing Record 47 of Set 8 | broken hill
# Processing Record 48 of Set 8 | honiara
# Processing Record 49 of Set 8 | pedernales
# Processing Record 50 of Set 8 | macau
# Processing Record 1 of Set 9 | apsheronsk
# Processing Record 2 of Set 9 | voykove
# Processing Record 3 of Set 9 | pandamatenga
# Processing Record 4 of Set 9 | chicama
# Processing Record 5 of Set 9 | ondorhaan
# City ondorhaan not found. Skipping...
# Processing Record 6 of Set 9 | walvis bay
# Processing Record 7 of Set 9 | narsaq
# Processing Record 8 of Set 9 | khasan
# Processing Record 9 of Set 9 | kuche
# City kuche not found. Skipping...
# Processing Record 10 of Set 9 | idlib
# Processing Record 11 of Set 9 | perevolotskiy
# Processing Record 12 of Set 9 | najran
# Processing Record 13 of Set 9 | san andres
# Processing Record 14 of Set 9 | lolua
# City lolua not found. Skipping...
# Processing Record 15 of Set 9 | old road
# City old road not found. Skipping...
# Processing Record 16 of Set 9 | gweru
# Processing Record 17 of Set 9 | lexington park
# Processing Record 18 of Set 9 | ciamis
# Processing Record 19 of Set 9 | chara
# Processing Record 20 of Set 9 | sola
# Processing Record 21 of Set 9 | maun
# Processing Record 22 of Set 9 | kilindoni
# Processing Record 23 of Set 9 | glenluce
# Processing Record 24 of Set 9 | utmanzai
# Processing Record 25 of Set 9 | salekhard
# Processing Record 26 of Set 9 | baculin
# Processing Record 27 of Set 9 | nome
# Processing Record 28 of Set 9 | ouesso
# Processing Record 29 of Set 9 | saint-joseph
# Processing Record 30 of Set 9 | shelton
# Processing Record 31 of Set 9 | hualmay
# Processing Record 32 of Set 9 | mafeteng
# Processing Record 33 of Set 9 | ye
# City ye not found. Skipping...
# Processing Record 34 of Set 9 | maryborough
# Processing Record 35 of Set 9 | cervo
# Processing Record 36 of Set 9 | stepnyak
# Processing Record 37 of Set 9 | vilhena
# Processing Record 38 of Set 9 | bosilegrad
# Processing Record 39 of Set 9 | kampene
# Processing Record 40 of Set 9 | tonj
# Processing Record 41 of Set 9 | ransang
# Processing Record 42 of Set 9 | salalah
# Processing Record 43 of Set 9 | saldanha
# Processing Record 44 of Set 9 | bilibino
# Processing Record 45 of Set 9 | salmo
# Processing Record 46 of Set 9 | rio gallegos
# Processing Record 47 of Set 9 | arumbavur
# Processing Record 48 of Set 9 | ajaccio
# Processing Record 49 of Set 9 | la asuncion
# Processing Record 50 of Set 9 | talnakh
# Processing Record 1 of Set 10 | penzance
# Processing Record 2 of Set 10 | gizo
# Processing Record 3 of Set 10 | illapel
# Processing Record 4 of Set 10 | wahpeton
# Processing Record 5 of Set 10 | alofi
# Processing Record 6 of Set 10 | kisangani
# Processing Record 7 of Set 10 | touzim
# Processing Record 8 of Set 10 | yuci
# Processing Record 9 of Set 10 | arroio dos ratos
# Processing Record 10 of Set 10 | wahran
# City wahran not found. Skipping...
# Processing Record 11 of Set 10 | kusk
# City kusk not found. Skipping...
# Processing Record 12 of Set 10 | metlaltoyuca
# Processing Record 13 of Set 10 | carbondale
# Processing Record 14 of Set 10 | shenkursk
# Processing Record 15 of Set 10 | peace river
# Processing Record 16 of Set 10 | altamira
# Processing Record 17 of Set 10 | moree
# Processing Record 18 of Set 10 | igarka
# Processing Record 19 of Set 10 | matagami
# Processing Record 20 of Set 10 | carmarthen
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | zaysan
# Processing Record 23 of Set 10 | sorong
# Processing Record 24 of Set 10 | bengkulu
# Processing Record 25 of Set 10 | la grande
# Processing Record 26 of Set 10 | dawei
# Processing Record 27 of Set 10 | vila
# Processing Record 28 of Set 10 | santiago del estero
# Processing Record 29 of Set 10 | christchurch
# Processing Record 30 of Set 10 | lamesa
# Processing Record 31 of Set 10 | zolotinka
# City zolotinka not found. Skipping...
# Processing Record 32 of Set 10 | manoel urbano
# Processing Record 33 of Set 10 | camocim
# Processing Record 34 of Set 10 | krasnovishersk
# Processing Record 35 of Set 10 | periam
# Processing Record 36 of Set 10 | itapirapua
# Processing Record 37 of Set 10 | laguna
# Processing Record 38 of Set 10 | seoul
# Processing Record 39 of Set 10 | kawalu
# Processing Record 40 of Set 10 | nuuk
# Processing Record 41 of Set 10 | elko
# Processing Record 42 of Set 10 | sanwer
# Processing Record 43 of Set 10 | meyungs
# City meyungs not found. Skipping...
# Processing Record 44 of Set 10 | saint-pierre
# Processing Record 45 of Set 10 | tura
# Processing Record 46 of Set 10 | sao gabriel da cachoeira
# Processing Record 47 of Set 10 | arlit
# Processing Record 48 of Set 10 | calamar
# Processing Record 49 of Set 10 | nyrob
# Processing Record 50 of Set 10 | rawson
# Processing Record 1 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 11 | aklavik
# Processing Record 3 of Set 11 | mitu
# Processing Record 4 of Set 11 | abu dhabi
# Processing Record 5 of Set 11 | bassila
# Processing Record 6 of Set 11 | salta
# Processing Record 7 of Set 11 | timmins
# Processing Record 8 of Set 11 | wajir
# Processing Record 9 of Set 11 | umzimvubu
# City umzimvubu not found. Skipping...
# Processing Record 10 of Set 11 | trat
# Processing Record 11 of Set 11 | morondava
# Processing Record 12 of Set 11 | dandong
# Processing Record 13 of Set 11 | awbari
# Processing Record 14 of Set 11 | kazalinsk
# City kazalinsk not found. Skipping...
# Processing Record 15 of Set 11 | dicabisagan
# Processing Record 16 of Set 11 | cairns
# Processing Record 17 of Set 11 | homer
# Processing Record 18 of Set 11 | shishou
# Processing Record 19 of Set 11 | sile
# Processing Record 20 of Set 11 | cotonou
# Processing Record 21 of Set 11 | kieta
# Processing Record 22 of Set 11 | mpanda
# Processing Record 23 of Set 11 | portland
# Processing Record 24 of Set 11 | salihorsk
# Processing Record 25 of Set 11 | shelburne
# Processing Record 26 of Set 11 | tara
# Processing Record 27 of Set 11 | srandakan
# Processing Record 28 of Set 11 | tawkar
# City tawkar not found. Skipping...
# Processing Record 29 of Set 11 | okha
# Processing Record 30 of Set 11 | nanyang
# Processing Record 31 of Set 11 | huilong
# Processing Record 32 of Set 11 | wellingborough
# Processing Record 33 of Set 11 | maloy
# Processing Record 34 of Set 11 | kavieng
# Processing Record 35 of Set 11 | rungata
# City rungata not found. Skipping...
# Processing Record 36 of Set 11 | vawkavysk
# Processing Record 37 of Set 11 | bereda
# Processing Record 38 of Set 11 | praya
# Processing Record 39 of Set 11 | ewa beach
# Processing Record 40 of Set 11 | burgeo
# Processing Record 41 of Set 11 | bijar
# Processing Record 42 of Set 11 | karaul
# City karaul not found. Skipping...
# Processing Record 43 of Set 11 | puerto del rosario
# Processing Record 44 of Set 11 | kaeo
# Processing Record 45 of Set 11 | dawson creek
# Processing Record 46 of Set 11 | lanzhou
# Processing Record 47 of Set 11 | catamarca
# Processing Record 48 of Set 11 | sergeyevka
# Processing Record 49 of Set 11 | scalloway
# City scalloway not found. Skipping...
# Processing Record 50 of Set 11 | batagay-alyta
# Processing Record 1 of Set 12 | herat
# Processing Record 2 of Set 12 | buchanan
# Processing Record 3 of Set 12 | bolungarvik
# City bolungarvik not found. Skipping...
# Processing Record 4 of Set 12 | lewistown
# Processing Record 5 of Set 12 | waipawa
# Processing Record 6 of Set 12 | inhambane
# Processing Record 7 of Set 12 | puro
# Processing Record 8 of Set 12 | olavarria
# Processing Record 9 of Set 12 | kerman
# Processing Record 10 of Set 12 | los zacatones
# Processing Record 11 of Set 12 | dubasari
# Processing Record 12 of Set 12 | cockburn town
# Processing Record 13 of Set 12 | hukuntsi
# Processing Record 14 of Set 12 | khonuu
# City khonuu not found. Skipping...
# Processing Record 15 of Set 12 | maskinonge
# Processing Record 16 of Set 12 | bossier city
# Processing Record 17 of Set 12 | juegang
# Processing Record 18 of Set 12 | lovozero
# Processing Record 19 of Set 12 | kabompo
# Processing Record 20 of Set 12 | atambua
# Processing Record 21 of Set 12 | aldan
# Processing Record 22 of Set 12 | gunnedah
# Processing Record 23 of Set 12 | dunedin
# Processing Record 24 of Set 12 | maryville
# Processing Record 25 of Set 12 | coos bay
# Processing Record 26 of Set 12 | catabola
# Processing Record 27 of Set 12 | zurrieq
# Processing Record 28 of Set 12 | kungurtug
# Processing Record 29 of Set 12 | olga
# Processing Record 30 of Set 12 | bac lieu
# Processing Record 31 of Set 12 | barrhead
# Processing Record 32 of Set 12 | barbar
# City barbar not found. Skipping...
# Processing Record 33 of Set 12 | lamu
# Processing Record 34 of Set 12 | flin flon
# Processing Record 35 of Set 12 | lazurne
# Processing Record 36 of Set 12 | miranorte
# City miranorte not found. Skipping...
# Processing Record 37 of Set 12 | floro
# Processing Record 38 of Set 12 | churapcha
# Processing Record 39 of Set 12 | xapuri
# Processing Record 40 of Set 12 | marondera
# Processing Record 41 of Set 12 | fort morgan
# Processing Record 42 of Set 12 | half moon bay
# Processing Record 43 of Set 12 | tigil
# Processing Record 44 of Set 12 | rapid valley
# Processing Record 45 of Set 12 | canico
# Processing Record 46 of Set 12 | palabuhanratu
# City palabuhanratu not found. Skipping...
# Processing Record 47 of Set 12 | hounde
# Processing Record 48 of Set 12 | taybad
# Processing Record 49 of Set 12 | port moresby
# Processing Record 50 of Set 12 | grand forks
# Processing Record 1 of Set 13 | holetown
# Processing Record 2 of Set 13 | bontang
# Processing Record 3 of Set 13 | srivardhan
# Processing Record 4 of Set 13 | sehithwa
# Processing Record 5 of Set 13 | lujan
# Processing Record 6 of Set 13 | nikolayevsk-na-amure
# Processing Record 7 of Set 13 | jalu
# Processing Record 8 of Set 13 | atar
# Processing Record 9 of Set 13 | pacifica
# Processing Record 10 of Set 13 | ulagan
# Processing Record 11 of Set 13 | sorland
# Processing Record 12 of Set 13 | eyl
# Processing Record 13 of Set 13 | sokoto
# Processing Record 14 of Set 13 | port hardy
# Processing Record 15 of Set 13 | port hedland
# Processing Record 16 of Set 13 | lopez jaena
# Processing Record 17 of Set 13 | sulangan
# Processing Record 18 of Set 13 | edd
# Processing Record 19 of Set 13 | pontianak
# Processing Record 20 of Set 13 | yaan
# Processing Record 21 of Set 13 | hami
# Processing Record 22 of Set 13 | vila franca do campo
# Processing Record 23 of Set 13 | aleksandrov gay
# Processing Record 24 of Set 13 | lerwick
# Processing Record 25 of Set 13 | roald
# Processing Record 26 of Set 13 | chanute
# Processing Record 27 of Set 13 | marzuq
# Processing Record 28 of Set 13 | labuhan
# Processing Record 29 of Set 13 | muros
# Processing Record 30 of Set 13 | matinha
# Processing Record 31 of Set 13 | alexandria
# Processing Record 32 of Set 13 | samarai
# Processing Record 33 of Set 13 | grasse
# Processing Record 34 of Set 13 | jilin
# Processing Record 35 of Set 13 | longlac
# City longlac not found. Skipping...
# Processing Record 36 of Set 13 | waddan
# Processing Record 37 of Set 13 | smithers
# Processing Record 38 of Set 13 | puerto colombia
# Processing Record 39 of Set 13 | jardim
# Processing Record 40 of Set 13 | yulara
# Processing Record 41 of Set 13 | kayseri
# Processing Record 42 of Set 13 | luganville
# Processing Record 43 of Set 13 | deputatskiy
# Processing Record 44 of Set 13 | ciudad bolivar
# Processing Record 45 of Set 13 | wagar
# Processing Record 46 of Set 13 | imbituba
# Processing Record 47 of Set 13 | erithrai
# City erithrai not found. Skipping...
# Processing Record 48 of Set 13 | amot
# Processing Record 49 of Set 13 | brownwood
# Processing Record 50 of Set 13 | broome
# Processing Record 1 of Set 14 | la crosse
# Processing Record 2 of Set 14 | acarau
# Processing Record 3 of Set 14 | papillion
# Processing Record 4 of Set 14 | mariental
# Processing Record 5 of Set 14 | sitka
# Processing Record 6 of Set 14 | mackay
# Processing Record 7 of Set 14 | bayir
# Processing Record 8 of Set 14 | le port
# Processing Record 9 of Set 14 | massakory
# Processing Record 10 of Set 14 | pavino
# Processing Record 11 of Set 14 | usinsk
# Processing Record 12 of Set 14 | klungkung
# Processing Record 13 of Set 14 | kidal
# Processing Record 14 of Set 14 | lisakovsk
# Processing Record 15 of Set 14 | la ligua
# Processing Record 16 of Set 14 | flinders
# Processing Record 17 of Set 14 | naze
# Processing Record 18 of Set 14 | nioki
# Processing Record 19 of Set 14 | daokou
# Processing Record 20 of Set 14 | tete
# Processing Record 21 of Set 14 | lodja
# Processing Record 22 of Set 14 | pisco
# Processing Record 23 of Set 14 | vysokogornyy
# Processing Record 24 of Set 14 | kilis
# Processing Record 25 of Set 14 | bitung
# Processing Record 26 of Set 14 | balanesti
# Processing Record 27 of Set 14 | himora
# City himora not found. Skipping...
# Processing Record 28 of Set 14 | butembo
# Processing Record 29 of Set 14 | irituia
# Processing Record 30 of Set 14 | bilma
# Processing Record 31 of Set 14 | yatou
# Processing Record 32 of Set 14 | san nicolas
# Processing Record 33 of Set 14 | copiapo
# Processing Record 34 of Set 14 | perigueux
# Processing Record 35 of Set 14 | sterling
# Processing Record 36 of Set 14 | mbaiki
# Processing Record 37 of Set 14 | letlhakeng
# Processing Record 38 of Set 14 | halifax
# Processing Record 39 of Set 14 | sao felix do xingu
# Processing Record 40 of Set 14 | seydi
# Processing Record 41 of Set 14 | lufilufi
# Processing Record 42 of Set 14 | zhigansk
# Processing Record 43 of Set 14 | sinjah
# City sinjah not found. Skipping...
# Processing Record 44 of Set 14 | coetupo
# City coetupo not found. Skipping...
# Processing Record 45 of Set 14 | maldonado
# Processing Record 46 of Set 14 | sioux lookout
# Processing Record 47 of Set 14 | lieksa
# Processing Record 48 of Set 14 | manggar
# Processing Record 49 of Set 14 | katsuura
# Processing Record 50 of Set 14 | moroni
# Processing Record 1 of Set 15 | jiazi
# Processing Record 2 of Set 15 | west wendover
# Processing Record 3 of Set 15 | aswan
# Processing Record 4 of Set 15 | kipushi
# Processing Record 5 of Set 15 | palpa
# Processing Record 6 of Set 15 | denpasar
# Processing Record 7 of Set 15 | cedar city
# Processing Record 8 of Set 15 | saraikela
# Processing Record 9 of Set 15 | barinas
# Processing Record 10 of Set 15 | lucera
# Processing Record 11 of Set 15 | udachnyy
# Processing Record 12 of Set 15 | peachland
# Processing Record 13 of Set 15 | stelle
# Processing Record 14 of Set 15 | gayny
# Processing Record 15 of Set 15 | horsham
# Processing Record 16 of Set 15 | anito
# Processing Record 17 of Set 15 | rafaela
# Processing Record 18 of Set 15 | barabai
# Processing Record 19 of Set 15 | roma
# Processing Record 20 of Set 15 | krasnoarmeysk
# Processing Record 21 of Set 15 | ancud
# Processing Record 22 of Set 15 | bandar-e torkaman
# City bandar-e torkaman not found. Skipping...
# Processing Record 23 of Set 15 | minudasht
# Processing Record 24 of Set 15 | port lincoln
# Processing Record 25 of Set 15 | presidencia roque saenz pena
# Processing Record 26 of Set 15 | oga
# Processing Record 27 of Set 15 | trapani
# Processing Record 28 of Set 15 | mango
# Processing Record 29 of Set 15 | khandyga
# Processing Record 30 of Set 15 | macon
# Processing Record 31 of Set 15 | karanja
# Processing Record 32 of Set 15 | prince rupert
# Processing Record 33 of Set 15 | pokhara
# Processing Record 34 of Set 15 | nha trang
# Processing Record 35 of Set 15 | humboldt
# Processing Record 36 of Set 15 | analipsis
# Processing Record 37 of Set 15 | abu samrah
# Processing Record 38 of Set 15 | porlamar
# Processing Record 39 of Set 15 | korla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hermanus      ZA -34.4187   19.2345     63.81        74          85
# 1         Algiers      DZ  36.7525    3.0420     57.02        94          75
# 2  Mont-De-Marsan      FR  44.0000   -0.6667     60.28        57           0
# 3       Hithadhoo      MV  -0.6000   73.0833     83.44        68           0
# 4            Daru      PG  -9.0763  143.2092     76.89        89         100
# 5    San Patricio      US  28.0170  -97.5169     89.69        23           0
# 6          Albany      US  42.6001  -73.9662     47.88        75         100
# 7      Bredasdorp      ZA -34.5322   20.0403     64.20        72          16
# 8         Te Anau      NZ -45.4167  167.7167     47.52        97          55
# 9           Suixi      CN  33.8907  116.7747     50.07        85         100
#
#    Wind Speed Current Description
# 0       14.88     overcast clouds
# 1        6.91       moderate rain
# 2        6.91           clear sky
# 3       13.27           clear sky
# 4        5.17       moderate rain
# 5       12.33           clear sky
# 6        3.00       moderate rain
# 7       14.07          few clouds
# 8        0.92       broken clouds
# 9        6.82     overcast clouds

# %%
# Save Data to csv
city_data_df.to_csv("C:/Users/raney/OneDrive/Desktop/Analysis_Projects/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv")
