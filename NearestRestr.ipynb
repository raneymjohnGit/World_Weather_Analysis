# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import g_key

# %%
types_df = pd.read_csv("C:/Users/raney/OneDrive/Desktop/Analysis_Projects/World_Weather_Analysis/Resources/ethnic_restr.csv")
types_df.head()
# Out:
#   ethnicity
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# set up additional columns to hold information
types_df['name'] = ""
types_df['address'] = ""
types_df['price_level'] = ""
types_df['rating'] = ""

types_df.head()
# Out:
#   ethnicity name address price_level rating
# 0   chinese
# 1     cuban
# 2     czech
# 3    french
# 4    german

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "33.2169231,-96.7556932",  # Mckinney coords
    "rankby": "distance",
    "type": "restaurant",
    "key": g_key,
}
# use iterrows to iterate through pandas dataframe
for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = row['ethnicity']

    # add keyword to params dict
    params['keyword'] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest {restr_type} restaurant is {results[0]['name']}.")
        
        types_df.loc[index, 'name'] = results[0]['name']
        types_df.loc[index, 'address'] = results[0]['vicinity']
        types_df.loc[index, 'price_level'] = results[0]['price_level']
        types_df.loc[index, 'rating'] = results[0]['rating']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: chinese.
# Closest chinese restaurant is Panda Express.
# ------------
# Retrieving Results for Index 1: cuban.
# Closest cuban restaurant is The Guava Tree Cuban Cafe & Cantina.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 2: czech.
# Closest czech restaurant is Taste of Poland European Tavern.
# ------------
# Retrieving Results for Index 3: french.
# Closest french restaurant is 11|17.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 4: german.
# Closest german restaurant is Hoff's Steaks and Steins.
# ------------
# Retrieving Results for Index 5: greek.
# Closest greek restaurant is Sheesh kitchen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 6: haitian.
# Closest haitian restaurant is Taste of the Islands.
# ------------
# Retrieving Results for Index 7: hungarian.
# Closest hungarian restaurant is Degenhardt's Brat Haus.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 8: indian.
# Closest indian restaurant is Bawarchi Biryani.
# ------------
# Retrieving Results for Index 9: indonesian.
# Closest indonesian restaurant is Secret Recipe.
# ------------
# Retrieving Results for Index 10: irish.
# Closest irish restaurant is E.J. Wills Gastropub.
# ------------
# Retrieving Results for Index 11: israeli.
# Closest israeli restaurant is Sheesh kitchen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 12: italian.
# Closest italian restaurant is Italian Garden.
# ------------
# Retrieving Results for Index 13: japanese.
# Closest japanese restaurant is Rice & Noodle.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 14: jewish.
# Closest jewish restaurant is DELI NEWS FRISCO.
# ------------
# Retrieving Results for Index 15: korean.
# Closest korean restaurant is Gen Korean BBQ House.
# ------------
# Retrieving Results for Index 16: lebanese.
# Closest lebanese restaurant is Sheesh kitchen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 17: mexican.
# Closest mexican restaurant is Mi Luna Great Tex-Mex.
# ------------
# Retrieving Results for Index 18: new american.
# Closest new american restaurant is 11|17.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 19: pakistani.
# Closest pakistani restaurant is Desi District (McKinney)-Restaurant, Halal Meat & Groceries.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 20: polish.
# Closest polish restaurant is Ogi's European Bakery and Deli - Healthy Homemade Sandwiches, Cakes, Meals.
# ------------
# Retrieving Results for Index 21: russian.
# Closest russian restaurant is Deluxe Restaurant and banquet hall.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 22: scandinavian.
# Closest scandinavian restaurant is Adriatica Village.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 23: scottish.
# Closest scottish restaurant is Delaney's Irish Pub & Scratch Kitchen.
# ------------
# Retrieving Results for Index 24: soul food.
# Closest soul food restaurant is Norma's Cafe.
# ------------
# Retrieving Results for Index 25: spanish.
# Closest spanish restaurant is Mi Luna Great Tex-Mex.
# ------------
# Retrieving Results for Index 26: thai.
# Closest thai restaurant is JoyThai Kitchen.
# ------------
# Retrieving Results for Index 27: turkish.
# Closest turkish restaurant is Sheesh kitchen.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 28: ukrainian.
# Closest ukrainian restaurant is Taste of Poland European Tavern.
# ------------
# Retrieving Results for Index 29: vietnamese.
# Closest vietnamese restaurant is Pho Que Huong - Noodle and Grill.
# ------------

# %%
types_df
# Out:
#        ethnicity                                               name  \
# 0        chinese                                      Panda Express
# 1          cuban                The Guava Tree Cuban Cafe & Cantina
# 2          czech                    Taste of Poland European Tavern
# 3         french                                              11|17
# 4         german                           Hoff's Steaks and Steins
# 5          greek                                     Sheesh kitchen
# 6        haitian                               Taste of the Islands
# 7      hungarian                             Degenhardt's Brat Haus
# 8         indian                                   Bawarchi Biryani
# 9     indonesian                                      Secret Recipe
# 10         irish                               E.J. Wills Gastropub
# 11       israeli                                     Sheesh kitchen
# 12       italian                                     Italian Garden
# 13      japanese                                      Rice & Noodle
# 14        jewish                                   DELI NEWS FRISCO
# 15        korean                               Gen Korean BBQ House
# 16      lebanese                                     Sheesh kitchen
# 17       mexican                              Mi Luna Great Tex-Mex
# 18  new american                                              11|17
# 19     pakistani  Desi District (McKinney)-Restaurant, Halal Mea...
# 20        polish  Ogi's European Bakery and Deli - Healthy Homem...
# 21       russian                 Deluxe Restaurant and banquet hall
# 22  scandinavian                                  Adriatica Village
# 23      scottish              Delaney's Irish Pub & Scratch Kitchen
# 24     soul food                                       Norma's Cafe
# 25       spanish                              Mi Luna Great Tex-Mex
# 26          thai                                    JoyThai Kitchen
# 27       turkish                                     Sheesh kitchen
# 28     ukrainian                    Taste of Poland European Tavern
# 29    vietnamese                   Pho Que Huong - Noodle and Grill
#
#                                       address  price_level  rating
# 0               2251 E University Dr, Prosper          1.0     3.3
# 1                 104 S Chestnut St, McKinney          2.0     4.4
# 2               2301 Central Expy #155, Plano          2.0     4.5
# 3     1910 N Stonebridge Dr STE 180, McKinney          4.0     4.0
# 4                   5454 Main St #123, Frisco          2.0     4.3
# 5                  1521 N Custer Rd, McKinney          2.0     4.2
# 6           909 Spring Creek Pkwy #300, Plano          2.0     4.2
# 7                   7800 Windrose Ave., Plano          2.0     4.2
# 8             4950 Eldorado Pkwy #400, Frisco          2.0     3.4
# 9      1404 W Hebron Pkwy Apt 103, Carrollton          2.0     4.2
# 10  1910 N Stonebridge Dr Suite 100, McKinney          2.0     4.3
# 11                 1521 N Custer Rd, McKinney          1.0     4.6
# 12             500 N Custer Rd #100, McKinney          2.0     4.5
# 13        1521 N Custer Rd STE 2600, McKinney          NaN     NaN
# 14               3685 Preston Rd #185, Frisco          2.0     4.5
# 15              9292 Warren Pkwy #150, Frisco          2.0     4.3
# 16                 1521 N Custer Rd, McKinney          1.0     4.6
# 17          2111 E University Dr #10, Prosper          2.0     4.2
# 18    1910 N Stonebridge Dr STE 180, McKinney          2.0     4.3
# 19        5400 Collin McKinney Pkwy, McKinney          NaN     NaN
# 20       1651 Eldorado Pkwy STE 108, McKinney          1.0     4.9
# 21              3291 Independence Pkwy, Plano          2.0     4.6
# 22            6602 Mediterranean Dr, McKinney          2.0     4.3
# 23          6150 Eldorado Pkwy #120, McKinney          2.0     4.3
# 24              8300 Gaylord Pkwy #19, Frisco          1.0     4.5
# 25          2111 E University Dr #10, Prosper          2.0     4.2
# 26               260 N Coit Rd #110, McKinney          2.0     4.3
# 27                 1521 N Custer Rd, McKinney          2.0     4.5
# 28              2301 Central Expy #155, Plano          2.0     4.5
# 29                 5110 Eldorado Pkwy, Frisco          1.0     4.1
